# %%
import pandas as pd

# %%
titanic_data = pd.read_csv("titanic.csv")
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
titanic_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_data.shape
# Out:
# (1309, 14)

# %%
titanic_data.columns # fare: pool bilit / parch: parent and childelren / sibsp : bardara o kgahar o ... /
# embark: bandar hayi ke savar shodn
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic_data = pd.read_csv("titanic.csv")
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
titanic_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic_data.shape
# Out:
# (1309, 14)

# %%
titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df = pd.DataFrame(titanic_data)
df.sample(3)
# Out:
#      pclass  survived                                  name     sex   age  \
# 663       3         0                     Balkic, Mr. Cerin    male  26.0
# 694       3         0                   Burke, Mr. Jeremiah    male  19.0
# 396       2         1  Doling, Mrs. John T (Ada Julia Bone)  female  34.0
#
#      sibsp  parch  ticket     fare cabin embarked boat  body  \
# 663      0      0  349248   7.8958   NaN        S  NaN   NaN
# 694      0      0  365222   6.7500   NaN        Q  NaN   NaN
# 396      0      1  231919  23.0000   NaN        S  NaN   NaN
#
#                             home.dest
# 663                               NaN
# 694  Co Cork, Ireland Charlestown, MA
# 396                       Southampton

# %%
tips = pd.read_csv(r"C:\Users\ATG\Desktop\Untitled Folder\in home\pandas\tips.csv")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# for another way import data
# import pandas as pd
# import os
# import glob

# path = os.getcwd()
# csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
pd.DataFrame(titanic_data).sample(7)
# Out:
#      pclass  survived                                               name  \
# 238       1         1  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...
# 290       1         0                                  Taussig, Mr. Emil
# 974       3         0                           Lobb, Mr. William Arthur
# 80        1         0                          Crafton, Mr. John Bertram
# 125       1         0                                   Fry, Mr. Richard
# 806       3         0               Ford, Miss. Doolina Margaret "Daisy"
# 961       3         0                                 Lennon, Miss. Mary
#
#         sex   age  sibsp  parch      ticket      fare cabin embarked boat  \
# 238  female  43.0      0      1       24160  211.3375    B3        S    2
# 290    male  52.0      1      1      110413   79.6500   E67        S  NaN
# 974    male  30.0      1      0   A/5. 3336   16.1000   NaN        S  NaN
# 80     male   NaN      0      0      113791   26.5500   NaN        S  NaN
# ...

# %%
titanic_data.head(-1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1303       3         0                            Yousseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1309 entries, 0 to 1308
#
# Data columns (total 14 columns):
#
#  #   Column     Non-Null Count  Dtype
#
# ---  ------     --------------  -----
#
#  0   pclass     1309 non-null   int64
#
#  1   survived   1309 non-null   int64
#
#  2   name       1309 non-null   object
#
#  3   sex        1309 non-null   object
#
#  4   age        1046 non-null   float64
#
#  5   sibsp      1309 non-null   int64
#
#  6   parch      1309 non-null   int64
#
#  7   ticket     1309 non-null   object
#
#  8   fare       1308 non-null   float64
#
#  9   cabin      295 non-null    object
#
#  10  embarked   1307 non-null   object
#
#  11  boat       486 non-null    object
#
#  12  body       121 non-null    float64
#
#  13  home.dest  745 non-null    object
#
# dtypes: float64(3), int64(4), object(7)
#
# memory usage: 143.3+ KB

# %%
titanic_data['survived'] # age yedoone fichter ro mikhay select koni [] mizri
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64

# %%
type(titanic_data['survived'])
# Out:
# pandas.core.series.Series

# %%
type(titanic_data[['survived', 'pclass']]) # age chanta fichter mikhay select koni [[]] mizri
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data[['survived', 'pclass']]
# Out:
#       survived  pclass
# 0            1       1
# 1            1       1
# 2            0       1
# 3            0       1
# 4            0       1
# ...        ...     ...
# 1304         0       3
# 1305         0       3
# 1306         0       3
# 1307         0       3
# 1308         0       3
#
# [1309 rows x 2 columns]

# %%
titanic_data['survived'][10:20] # baraye slecet kardan row(record)
# Out:
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# 15    0
# 16    0
# 17    1
# 18    1
# 19    0
# Name: survived, dtype: int64

# %%
titanic_data.survived[10:20]
# Out:
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# 15    0
# 16    0
# 17    1
# 18    1
# 19    0
# Name: survived, dtype: int64

# %%
titanic_data[['survived', 'age', 'fare']][10:20] # baraye select kardan chanta fiycher
# Out:
#     survived   age      fare
# 10         0  47.0  227.5250
# 11         1  18.0  227.5250
# 12         1  24.0   69.3000
# 13         1  26.0   78.8500
# 14         1  80.0   30.0000
# 15         0   NaN   25.9250
# 16         0  24.0  247.5208
# 17         1  50.0  247.5208
# 18         1  32.0   76.2917
# 19         0  36.0   75.2417

# %%
titanic_data['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
titanic_data['survived'].value_counts(normalize=True)* 100
# Out:
# 0    61.802903
# 1    38.197097
# Name: survived, dtype: float64

# %%
titanic_data[['survived', 'pclass']].value_counts(normalize=True)* 100
# Out:
# survived  pclass
# 0         3         40.336134
# 1         1         15.278839
#           3         13.827349
# 0         2         12.070283
#           1          9.396486
# 1         2          9.090909
# dtype: float64

# %%
pd.crosstab(titanic_data.sex, titanic_data.survived) #story telling,
# Out:
# survived    0    1
# sex
# female    127  339
# male      682  161

# %%
pd.crosstab(titanic_data.pclass, titanic_data.survived) #story telling,
# Out:
# survived    0    1
# pclass
# 1         123  200
# 2         158  119
# 3         528  181

# %%
pd.crosstab(titanic_data.sex, titanic_data.survived, normalize = "index" ) #story telling, normalize index
# Out:
# survived         0         1
# sex
# female    0.272532  0.727468
# male      0.809015  0.190985

# %%
pd.crosstab(titanic_data.sex, titanic_data.survived, normalize = "columns" ) #story telling, normalize columns
# Out:
# survived         0      1
# sex
# female    0.156984  0.678
# male      0.843016  0.322

# %%
pd.crosstab(titanic_data.pclass, titanic_data.survived, normalize = "index" )
# Out:
# survived         0         1
# pclass
# 1         0.380805  0.619195
# 2         0.570397  0.429603
# 3         0.744711  0.255289

# %%
pd.crosstab(titanic_data.pclass, titanic_data.survived, normalize = "columns" )
# Out:
# survived         0      1
# pclass
# 1         0.152040  0.400
# 2         0.195303  0.238
# 3         0.652658  0.362

# %%
pd.crosstab(titanic_data.pclass, titanic_data.survived, normalize = "all" )
# Out:
# survived         0         1
# pclass
# 1         0.093965  0.152788
# 2         0.120703  0.090909
# 3         0.403361  0.138273

# %%
below_5_years = titanic_data[titanic_data.age <= 5]
below_5_years
# Out:
#       pclass  survived                                      name     sex  \
# 1          1         1            Allison, Master. Hudson Trevor    male
# 2          1         0              Allison, Miss. Helen Loraine  female
# 94         1         1                 Dodge, Master. Washington    male
# 339        2         1                 Becker, Master. Richard F    male
# 340        2         1               Becker, Miss. Marion Louise  female
# 359        2         1             Caldwell, Master. Alden Gates    male
# 427        2         1                 Hamalainen, Master. Viljo    male
# 478        2         1                     Laroche, Miss. Louise  female
# 479        2         1  Laroche, Miss. Simonne Marie Anne Andree  female
# 492        2         1                     Mallet, Master. Andre    male
# 514        2         1            Navratil, Master. Edmond Roger    male
# 515        2         1                Navratil, Master. Michel M    male
# ...

# %%
len(below_5_years) # baraye tedad
# Out:
# 56

# %%
below_5_years.shape
# Out:
# (56, 14)

# %%
below_5_years['survived'].value_counts()
# Out:
# 1    37
# 0    19
# Name: survived, dtype: int64

# %%
titanic_data[titanic_data.age <= 5][['survived', 'age', 'pclass']]
# Out:
#       survived   age  pclass
# 1            1  0.92       1
# 2            0  2.00       1
# 94           1  4.00       1
# 339          1  1.00       2
# 340          1  4.00       2
# 359          1  0.83       2
# 427          1  0.67       2
# 478          1  1.00       2
# 479          1  3.00       2
# 492          1  1.00       2
# 514          1  2.00       2
# 515          1  3.00       2
# 540          1  2.00       2
# 548          1  0.83       2
# 549          1  3.00       2
# 587          1  2.00       2
# 588          1  4.00       2
# 590          1  0.92       2
# 591          1  5.00       2
# 611          1  0.83       3
# 622          0  4.00       3
# 624          0  2.00       3
# 639          0  5.00       3
# 641          1  3.00       3
# 643          1  5.00       3
# 657          1  0.75       3
# 658          1  0.75       3
# 659          1  5.00       3
# 734          1  3.00       3
# 747          0  0.33       3
# 762          1  1.00       3
# ...

# %%
titanic_data[titanic_data.name.str.contains('Allen', case=False)]
# Out:
#      pclass  survived                                              name  \
# 0         1         1                     Allen, Miss. Elisabeth Walton
# 342       2         1  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 618       3         0                          Allen, Mr. William Henry
#
#         sex   age  sibsp  parch  ticket      fare cabin embarked boat  body  \
# 0    female  29.0      0      0   24160  211.3375    B5        S    2   NaN
# 342  female  36.0      0      3  230136   39.0000    F4        S   11   NaN
# 618    male  35.0      0      0  373450    8.0500   NaN        S  NaN   NaN
#
#                                              home.dest
# 0                                         St Louis, MO
# 342                 Guntur, India / Benton Harbour, MI
# 618  Lower Clapton, Middlesex or Erdington, Birmingham

# %%
len(titanic_data[titanic_data.name.str.contains('Allen', case=False)])
# Out:
# 3

# %%
titanic_data.embarked.unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
titanic_data.embarked.value_counts() #vali tedad nan ro neshoon nemide
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
titanic_data[ ( titanic_data.survived == 1 ) & ( titanic_data.age <= 5) ][['age', 'sex', 'pclass']][10:20]
# Out:
#       age     sex  pclass
# 515  3.00    male       2
# 540  2.00  female       2
# 548  0.83    male       2
# 549  3.00    male       2
# 587  2.00    male       2
# 588  4.00  female       2
# 590  0.92  female       2
# 591  5.00  female       2
# 611  0.83    male       3
# 641  3.00    male       3

# %%
titanic_data[ titanic_data.age.isnull() ]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex  age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
titanic_data[ titanic_data.age.isnull() ] [['sex', 'survived', 'age', 'pclass']]
# Out:
#          sex  survived  age  pclass
# 15      male         0  NaN       1
# 37      male         1  NaN       1
# 40      male         0  NaN       1
# 46      male         0  NaN       1
# 59    female         1  NaN       1
# ...      ...       ...  ...     ...
# 1293    male         0  NaN       3
# 1297    male         0  NaN       3
# 1302    male         0  NaN       3
# 1303    male         0  NaN       3
# 1305  female         0  NaN       3
#
# [263 rows x 4 columns]

# %%
titanic_data[ -titanic_data.age.isnull() ] [['sex', 'survived', 'age', 'pclass']] [0:5]
# Out:
#       sex  survived    age  pclass
# 0  female         1  29.00       1
# 1    male         1   0.92       1
# 2  female         0   2.00       1
# 3    male         0  30.00       1
# 4  female         0  25.00       1

# %%
titanic_data[ titanic_data.age.notnull() ] [['sex', 'survived', 'age', 'pclass']] [0:5]
# Out:
#       sex  survived    age  pclass
# 0  female         1  29.00       1
# 1    male         1   0.92       1
# 2  female         0   2.00       1
# 3    male         0  30.00       1
# 4  female         0  25.00       1

# %%
titanic_data.groupby( 'pclass')['fare'].mean()
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
pclass_age_mean_df = titanic_data.groupby('pclass')['age'].mean().reset_index()
pclass_age_mean_df
# Out:
#    pclass        age
# 0       1  39.159930
# 1       2  29.506705
# 2       3  24.816367

# %%
pclass_age_mean_df = titanic_data.groupby(['pclass', 'sex'])['age'].mean().reset_index()
pclass_age_mean_df
# Out:
#    pclass     sex        age
# 0       1  female  37.037594
# 1       1    male  41.029272
# 2       2  female  27.499223
# 3       2    male  30.815380
# 4       3  female  22.185329
# 5       3    male  25.962264

# %%
pclass_gender_age_mean_df = titanic_data.groupby(['pclass', 'sex'],as_index=False)['fare', 'age'].mean()
pclass_gender_age_mean_df
# Out:
# C:\Users\ATG\AppData\Local\Temp\ipykernel_8064\4186503205.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   pclass_gender_age_mean_df = titanic_data.groupby(['pclass', 'sex'],as_index=False)['fare', 'age'].mean()
#    pclass     sex        fare        age
# 0       1  female  109.412385  37.037594
# 1       1    male   69.888385  41.029272
# 2       2  female   23.234827  27.499223
# 3       2    male   19.904946  30.815380
# 4       3  female   15.324250  22.185329
# 5       3    male   12.415462  25.962264

# %%
titanic_data.sort_values('age', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 135        1         0                          Goldschmidt, Mr. George B
# 9          1         0                            Artagaveytia, Mr. Ramon
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...
